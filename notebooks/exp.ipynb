# %%
from src.agents.research_agent import agent
from src.utils.notebook_utils import stream_agent
import dotenv
# dotenv.load_dotenv()

# %%
import os
os.getenv("LANGSMITH_API_KEY")

# %%
state = {
    "messages":[
        {"role": "user", "content": "How to get job in BCG Canada"}
    ]
}
res = await stream_agent(agent, state)
